# %% [markdown]
# # Manuscript figure index
#
# Every paper figure is generated inside the notebook for its dataset (a `# >>> MANUSCRIPT FIGURE` cell at the end). This index maps figures to their source notebook; there is no separate figure-generation notebook.
#
# | Figure | Panel | Source notebook |
# |---|---|---|
# | Fig 1b | coupling matrix | 01_quickstart |
# | Fig 1c | worked query (motor→human) | 01_quickstart |
# | Fig 1d | evidence grade predicts accuracy | 02_trust_map |
# | Fig 2a | Beauchamp recovery (parcel/region) | 04_methodology |
# | Fig 2b | supervision build-up ablation | 04_methodology |
# | Fig 2c | held-out recovery by region | 03_anchor_packs |
# | Fig 3a | Coletta RSN vs spin null | 08_coletta |
# | Fig 3b | Fulcher structural hierarchy | 12_fulcher |
# | Fig 3c | principal gradient (boundary) | 07_margulies |
# | Fig 4  | TransBrain localization + cycle-consistency | 14_transbrain |
# | Fig 5a | BICCN E/I axis | 10_biccn |
# | Fig 5b | coverage: sensorimotor vs association | 15_buckner |
# | Fig 5c | mouse-coverage gradient span | 12_fulcher |
# | Fig 5d | uncovered-territory map | 15_buckner |
# | Fig 6a | autism re-subtyping agreement | 05_pagani |
#
# Panels are written to `../manuscript/figures/`. Extended Data panels (ablation grid, 23-marker table, ENIGMA, Schaeffer MFC, continuous non-survivors) live in their dataset notebooks likewise.
#
#
# ## Extended & synthesis panels (added later)
#
# Panels built after the initial figure set. Each regenerates via a `# >>> MANUSCRIPT FIGURE (extra session panels)` cell in the listed notebook; cross-dataset syntheses live in **17_cross_dataset_synthesis**.
#
# | Panel(s) | What | Source notebook |
# |---|---|---|
# | Fig 4 extras | TransBrain localisation, gradient/cycle/consensus/phenotype brain maps, ASD risk concordance | 14_transbrain |
# | Fig 5a set | E/I scatter, spin-null, specificity bar, 23-marker strip, E/I brain maps | 10_biccn (E/I) · 15_buckner (maps) |
# | Fig 5 coverage | tertile gap, deciles, coverage×gradient, ECDF, uncovered-territory map | 15_buckner |
# | Fig 5c + controls | gradient-span compression; dlPFC 0% falsification; coverage×myelin null | 12_fulcher |
# | Transcriptomic cross-check | independent convergent validity (π vs 51-gene panel, z≈10) | 17_synthesis |
# | Conservation spectrum | every result by evidence × granularity (survives/partial/null) | 17_synthesis |
# | Connectional-not-molecular | coverage collapses over association cortex, transcriptomic similarity does not | 17_synthesis |
# | Beauchamp systems ladder + Whitesell DMN | per-system validation; mouse-DMN refinement | 17_synthesis |
#
# Panels are written to `../manuscript/figures/` (subfolders `fig4/`, `fig5/`, `fig_extra/`).
#
# ## Earlier-figure additions (later round)
#
# | Panel | What | Source notebook |
# |---|---|---|
# | Fig 1 | topographic preservation (r=0.61) + mapping sharpness/posteriors | 01_quickstart |
# | Fig 2 | held-out anchor generalisation (hidden anchors top-1=100%) | 04_methodology |
# | Fig 3 | principal-gradient scatter (r=0.40, partial) | 07_margulies |
# | Fig 3 | network confusion heatmap (mouse×human RSN) | 08_coletta |
#
# | Fig 1 | motivation: why cross-species translation is hard (conserved / one-to-many / no-counterpart / size) | 01_quickstart |
